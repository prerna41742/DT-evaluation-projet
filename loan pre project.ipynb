# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("loan_prediction.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
sns.histplot(df['Loan_Status'])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
sns.countplot(x=df['Education'],hue=df['Loan_Status'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot(x=df['Self_Employed'],hue=df['Loan_Status'])
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %%
sns.countplot(x=df['Gender'],hue=df['Loan_Status'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x=df['Property_Area'],hue=df['Loan_Status'])
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %%
sns.countplot(x=df['Married'],hue=df['Loan_Status'])
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
dict1 = {'Graduate':1,'Not Graduate': 0}

# %%
df['Education']=df['Education'].replace(dict1)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents  Education Self_Employed  \
# 0    LP001002    Male      No          0          1            No
# 1    LP001003    Male     Yes          1          1            No
# 2    LP001005    Male     Yes          0          1           Yes
# 3    LP001006    Male     Yes          0          0            No
# 4    LP001008    Male      No          0          1            No
# ..        ...     ...     ...        ...        ...           ...
# 609  LP002978  Female      No          0          1            No
# 610  LP002979    Male     Yes         3+          1            No
# 611  LP002983    Male     Yes          1          1            No
# 612  LP002984    Male     Yes          2          1            No
# 613  LP002990  Female      No          0          1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
dict2 = {'Yes':1,'No':2}

# %%
df['Married']=df['Married'].replace(dict2)

# %%
#Label Encoding 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Loan_ID']=le.fit_transform(df['Loan_ID'])
df.head()
# Out:
#    Loan_ID Gender  Married Dependents  Education Self_Employed  \
# 0        0   Male      2.0          0          1            No
# 1        1   Male      1.0          1          1            No
# 2        2   Male      1.0          0          1           Yes
# 3        3   Male      1.0          0          0            No
# 4        4   Male      2.0          0          1            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
dict3 = {'Male':1,'Female':0}
df['Gender']=df['Gender'].replace(dict3)

# %%
df
# Out:
#      Loan_ID  Gender  Married Dependents  Education Self_Employed  \
# 0          0     1.0      2.0          0          1            No
# 1          1     1.0      1.0          1          1            No
# 2          2     1.0      1.0          0          1           Yes
# 3          3     1.0      1.0          0          0            No
# 4          4     1.0      2.0          0          1            No
# ..       ...     ...      ...        ...        ...           ...
# 609      609     0.0      2.0          0          1            No
# 610      610     1.0      1.0         3+          1            No
# 611      611     1.0      1.0          1          1            No
# 612      612     1.0      1.0          2          1            No
# 613      613     0.0      2.0          0          1           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
dict4={'Yes':1,'No':0}
df['Self_Employed']=df['Self_Employed'].replace(dict4)

# %%
df['Dependents'].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
df.describe()
# Out:
#           Loan_ID      Gender     Married   Education  Self_Employed  \
# count  614.000000  601.000000  611.000000  614.000000     582.000000
# mean   306.500000    0.813644    1.348609    0.781759       0.140893
# std    177.390811    0.389718    0.476920    0.413389       0.348211
# min      0.000000    0.000000    1.000000    0.000000       0.000000
# 25%    153.250000    1.000000    1.000000    1.000000       0.000000
# 50%    306.500000    1.000000    1.000000    1.000000       0.000000
# 75%    459.750000    1.000000    2.000000    1.000000       0.000000
# max    613.000000    1.000000    2.000000    1.000000       1.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
del df['Dependents']

# %%
df
# Out:
#      Loan_ID  Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0          0     1.0      2.0          1            0.0             5849
# 1          1     1.0      1.0          1            0.0             4583
# 2          2     1.0      1.0          1            1.0             3000
# 3          3     1.0      1.0          0            0.0             2583
# 4          4     1.0      2.0          1            0.0             6000
# ..       ...     ...      ...        ...            ...              ...
# 609      609     0.0      2.0          1            0.0             2900
# 610      610     1.0      1.0          1            0.0             4106
# 611      611     1.0      1.0          1            0.0             8072
# 612      612     1.0      1.0          1            0.0             7583
# 613      613     0.0      2.0          1            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#     Property_Area Loan_Status
# 0           Urban           Y
# 1           Rural           N
# 2           Urban           Y
# 3           Urban           Y
# 4           Urban           Y
# ..            ...         ...
# 609         Rural           Y
# 610         Rural           Y
# 611         Urban           Y
# 612         Urban           Y
# 613     Semiurban           N
#
# [614 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    int32
#  1   Gender             601 non-null    float64
#  2   Married            611 non-null    float64
#  3   Education          614 non-null    int64
#  4   Self_Employed      582 non-null    float64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(7), int32(1), int64(2), object(2)
# memory usage: 55.3+ KB

# %%
df['Urban']=df['Property_Area'].apply(lambda x : 1 if 'Urban' in x else 0)
df['Semi-Urban']=df['Property_Area'].apply(lambda x: 1 if 'Semiurban' in x else 0)
df['Rural']=df['Property_Area'].apply(lambda x: 1 if 'Rural' in x else 0)

# %%
df
# Out:
#      Loan_ID  Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0          0     1.0      2.0          1            0.0             5849
# 1          1     1.0      1.0          1            0.0             4583
# 2          2     1.0      1.0          1            1.0             3000
# 3          3     1.0      1.0          0            0.0             2583
# 4          4     1.0      2.0          1            0.0             6000
# ..       ...     ...      ...        ...            ...              ...
# 609      609     0.0      2.0          1            0.0             2900
# 610      610     1.0      1.0          1            0.0             4106
# 611      611     1.0      1.0          1            0.0             8072
# 612      612     1.0      1.0          1            0.0             7583
# 613      613     0.0      2.0          1            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#     Property_Area Loan_Status  Urban  Semi-Urban  Rural
# 0           Urban           Y      1           0      0
# 1           Rural           N      0           0      1
# 2           Urban           Y      1           0      0
# 3           Urban           Y      1           0      0
# 4           Urban           Y      1           0      0
# ..            ...         ...    ...         ...    ...
# 609         Rural           Y      0           0      1
# 610         Rural           Y      0           0      1
# 611         Urban           Y      1           0      0
# 612         Urban           Y      1           0      0
# 613     Semiurban           N      0           1      0
#
# [614 rows x 15 columns]

# %%
del df['Property_Area']

# %%
df['Loan_Status']= le.fit_transform(df['Loan_Status'])

# %%
df
# Out:
#      Loan_ID  Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0          0     1.0      2.0          1            0.0             5849
# 1          1     1.0      1.0          1            0.0             4583
# 2          2     1.0      1.0          1            1.0             3000
# 3          3     1.0      1.0          0            0.0             2583
# 4          4     1.0      2.0          1            0.0             6000
# ..       ...     ...      ...        ...            ...              ...
# 609      609     0.0      2.0          1            0.0             2900
# 610      610     1.0      1.0          1            0.0             4106
# 611      611     1.0      1.0          1            0.0             8072
# 612      612     1.0      1.0          1            0.0             7583
# 613      613     0.0      2.0          1            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#      Loan_Status  Urban  Semi-Urban  Rural
# 0              1      1           0      0
# 1              0      0           0      1
# 2              1      1           0      0
# 3              1      1           0      0
# 4              1      1           0      0
# ..           ...    ...         ...    ...
# 609            1      0           0      1
# 610            1      0           0      1
# 611            1      1           0      0
# 612            1      1           0      0
# 613            0      0           1      0
#
# [614 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    int32
#  1   Gender             601 non-null    float64
#  2   Married            611 non-null    float64
#  3   Education          614 non-null    int64
#  4   Self_Employed      582 non-null    float64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Loan_Status        614 non-null    int32
#  11  Urban              614 non-null    int64
#  12  Semi-Urban         614 non-null    int64
#  13  Rural              614 non-null    int64
# dtypes: float64(7), int32(2), int64(5)
# memory usage: 62.5 KB

# %%
df['LoanAmount']=df['LoanAmount'].replace('NaN',146.412162)

# %%
df
# Out:
#      Loan_ID  Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0          0     1.0      2.0          1            0.0             5849
# 1          1     1.0      1.0          1            0.0             4583
# 2          2     1.0      1.0          1            1.0             3000
# 3          3     1.0      1.0          0            0.0             2583
# 4          4     1.0      2.0          1            0.0             6000
# ..       ...     ...      ...        ...            ...              ...
# 609      609     0.0      2.0          1            0.0             2900
# 610      610     1.0      1.0          1            0.0             4106
# 611      611     1.0      1.0          1            0.0             8072
# 612      612     1.0      1.0          1            0.0             7583
# 613      613     0.0      2.0          1            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# 3               2358.0       120.0             360.0             1.0
# 4                  0.0       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0        71.0             360.0             1.0
# 610                0.0        40.0             180.0             1.0
# 611              240.0       253.0             360.0             1.0
# 612                0.0       187.0             360.0             1.0
# 613                0.0       133.0             360.0             0.0
#
#      Loan_Status  Urban  Semi-Urban  Rural
# 0              1      1           0      0
# 1              0      0           0      1
# 2              1      1           0      0
# 3              1      1           0      0
# 4              1      1           0      0
# ..           ...    ...         ...    ...
# 609            1      0           0      1
# 610            1      0           0      1
# 611            1      1           0      0
# 612            1      1           0      0
# 613            0      0           1      0
#
# [614 rows x 14 columns]

# %%
sns.boxplot(x=df['CoapplicantIncome'])
plt.show()

# %%
df.drop(df[(df['CoapplicantIncome']>7000)].index,inplace=True)

# %%
sns.boxplot(x=df['CoapplicantIncome'])
plt.show()

# %%
sns.boxplot(x=df['ApplicantIncome'])
plt.show()

# %%
df.drop(df[(df['ApplicantIncome']>9000)].index,inplace=True)

# %%
sns.boxplot(x=df['ApplicantIncome'])
plt.show()

# %%
df.describe()
# Out:
#           Loan_ID      Gender     Married   Education  Self_Employed  \
# count  532.000000  524.000000  530.000000  532.000000     503.000000
# mean   306.148496    0.812977    1.350943    0.753759       0.115308
# std    177.846679    0.390303    0.477716    0.431226       0.319711
# min      0.000000    0.000000    1.000000    0.000000       0.000000
# 25%    153.750000    1.000000    1.000000    1.000000       0.000000
# 50%    306.500000    1.000000    1.000000    1.000000       0.000000
# 75%    459.250000    1.000000    2.000000    1.000000       0.000000
# max    613.000000    1.000000    2.000000    1.000000       1.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       532.000000         532.000000  513.000000        518.000000
# mean       3936.496241        1418.011128  128.327485        342.972973
# std        1641.744582        1492.935074   50.992321         65.540184
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2719.500000           0.000000   99.000000        360.000000
# 50%        3590.500000        1405.500000  122.000000        360.000000
# 75%        4847.250000        2303.000000  153.000000        360.000000
# max        8799.000000        6666.000000  376.000000        480.000000
#
#        Credit_History  Loan_Status       Urban  Semi-Urban       Rural
# count      487.000000    532.00000  532.000000  532.000000  532.000000
# mean         0.837782      0.68985    0.319549    0.383459    0.296992
# std          0.369029      0.46299    0.466741    0.486686    0.457363
# min          0.000000      0.00000    0.000000    0.000000    0.000000
# 25%          1.000000      0.00000    0.000000    0.000000    0.000000
# 50%          1.000000      1.00000    0.000000    0.000000    0.000000
# 75%          1.000000      1.00000    1.000000    1.000000    1.000000
# max          1.000000      1.00000    1.000000    1.000000    1.000000

# %%
sns.boxplot(x=df['LoanAmount'])
plt.show()

# %%
df.drop(df[(df['LoanAmount']>250)].index,inplace=True)

# %%
sns.boxplot(x= df['LoanAmount'])
plt.show()

# %%
df['CoapplicantIncome']=df['CoapplicantIncome'].replace(0.0,1429.562466)

# %%
df
# Out:
#      Loan_ID  Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0          0     1.0      2.0          1            0.0             5849
# 1          1     1.0      1.0          1            0.0             4583
# 2          2     1.0      1.0          1            1.0             3000
# 3          3     1.0      1.0          0            0.0             2583
# 4          4     1.0      2.0          1            0.0             6000
# ..       ...     ...      ...        ...            ...              ...
# 608      608     1.0      1.0          1            0.0             3232
# 609      609     0.0      2.0          1            0.0             2900
# 610      610     1.0      1.0          1            0.0             4106
# 612      612     1.0      1.0          1            0.0             7583
# 613      613     0.0      2.0          1            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          1429.562466         NaN             360.0             1.0
# 1          1508.000000       128.0             360.0             1.0
# 2          1429.562466        66.0             360.0             1.0
# 3          2358.000000       120.0             360.0             1.0
# 4          1429.562466       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 608        1950.000000       108.0             360.0             1.0
# 609        1429.562466        71.0             360.0             1.0
# 610        1429.562466        40.0             180.0             1.0
# 612        1429.562466       187.0             360.0             1.0
# 613        1429.562466       133.0             360.0             0.0
#
#      Loan_Status  Urban  Semi-Urban  Rural
# 0              1      1           0      0
# 1              0      0           0      1
# 2              1      1           0      0
# 3              1      1           0      0
# 4              1      1           0      0
# ..           ...    ...         ...    ...
# 608            1      0           0      1
# 609            1      0           0      1
# 610            1      0           0      1
# 612            1      1           0      0
# 613            0      0           1      0
#
# [514 rows x 14 columns]

# %%
df.rename(columns={'Semi-Urban':'Semi_Urban'}, inplace=True)

# %%
df['CoapplicantIncome']=df['CoapplicantIncome'].replace(0.0,1365.883113)

# %%
df
# Out:
#      Loan_ID  Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0          0     1.0      2.0          1            0.0             5849
# 1          1     1.0      1.0          1            0.0             4583
# 2          2     1.0      1.0          1            1.0             3000
# 3          3     1.0      1.0          0            0.0             2583
# 4          4     1.0      2.0          1            0.0             6000
# ..       ...     ...      ...        ...            ...              ...
# 608      608     1.0      1.0          1            0.0             3232
# 609      609     0.0      2.0          1            0.0             2900
# 610      610     1.0      1.0          1            0.0             4106
# 612      612     1.0      1.0          1            0.0             7583
# 613      613     0.0      2.0          1            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          1429.562466         NaN             360.0             1.0
# 1          1508.000000       128.0             360.0             1.0
# 2          1429.562466        66.0             360.0             1.0
# 3          2358.000000       120.0             360.0             1.0
# 4          1429.562466       141.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 608        1950.000000       108.0             360.0             1.0
# 609        1429.562466        71.0             360.0             1.0
# 610        1429.562466        40.0             180.0             1.0
# 612        1429.562466       187.0             360.0             1.0
# 613        1429.562466       133.0             360.0             0.0
#
#      Loan_Status  Urban  Semi_Urban  Rural
# 0              1      1           0      0
# 1              0      0           0      1
# 2              1      1           0      0
# 3              1      1           0      0
# 4              1      1           0      0
# ..           ...    ...         ...    ...
# 608            1      0           0      1
# 609            1      0           0      1
# 610            1      0           0      1
# 612            1      1           0      0
# 613            0      0           1      0
#
# [514 rows x 14 columns]

# %%
df['LoanAmount'].dtype
# Out:
# dtype('float64')

# %%
df['LoanAmount']=df['LoanAmount'].replace(np.NaN,122.610101)

# %%
df
# Out:
#      Loan_ID  Gender  Married  Education  Self_Employed  ApplicantIncome  \
# 0          0     1.0      2.0          1            0.0             5849
# 1          1     1.0      1.0          1            0.0             4583
# 2          2     1.0      1.0          1            1.0             3000
# 3          3     1.0      1.0          0            0.0             2583
# 4          4     1.0      2.0          1            0.0             6000
# ..       ...     ...      ...        ...            ...              ...
# 608      608     1.0      1.0          1            0.0             3232
# 609      609     0.0      2.0          1            0.0             2900
# 610      610     1.0      1.0          1            0.0             4106
# 612      612     1.0      1.0          1            0.0             7583
# 613      613     0.0      2.0          1            1.0             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          1429.562466  122.610101             360.0             1.0
# 1          1508.000000  128.000000             360.0             1.0
# 2          1429.562466   66.000000             360.0             1.0
# 3          2358.000000  120.000000             360.0             1.0
# 4          1429.562466  141.000000             360.0             1.0
# ..                 ...         ...               ...             ...
# 608        1950.000000  108.000000             360.0             1.0
# 609        1429.562466   71.000000             360.0             1.0
# 610        1429.562466   40.000000             180.0             1.0
# 612        1429.562466  187.000000             360.0             1.0
# 613        1429.562466  133.000000             360.0             0.0
#
#      Loan_Status  Urban  Semi_Urban  Rural
# 0              1      1           0      0
# 1              0      0           0      1
# 2              1      1           0      0
# 3              1      1           0      0
# 4              1      1           0      0
# ..           ...    ...         ...    ...
# 608            1      0           0      1
# 609            1      0           0      1
# 610            1      0           0      1
# 612            1      1           0      0
# 613            0      0           1      0
#
# [514 rows x 14 columns]

# %% [markdown]
# # Correlation

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')
plt.show()

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                8
# Married               2
# Education             0
# Self_Employed        28
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       41
# Loan_Status           0
# Urban                 0
# Semi_Urban            0
# Rural                 0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df['Gender'] = df['Gender'].replace(np.NaN,df['Gender'].mode()[0])

# %%
df['Gender'].unique()
# Out:
# array([1., 0.])

# %%
df['Self_Employed'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
df['Self_Employed'] = df['Self_Employed'].replace(np.NaN,df['Self_Employed'].mode()[0])

# %%
df['Self_Employed'].unique()
# Out:
# array([0., 1.])

# %%
df['Loan_Amount_Term'].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].replace(np.NaN,342.36)

# %%
df['Loan_Amount_Term'].unique()
# Out:
# array([360.  , 120.  , 240.  , 342.36, 180.  ,  60.  , 300.  , 480.  ,
#         36.  ,  84.  ,  12.  ])

# %%
df['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df['Credit_History'] = df['Credit_History'].replace(np.NaN,df['Credit_History'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              2
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Loan_Status          0
# Urban                0
# Semi_Urban           0
# Rural                0
# dtype: int64

# %%
df['Married'].unique()
# Out:
# array([ 2.,  1., nan])

# %%
df['Married']=df['Married'].replace(np.NaN,df['Married'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Loan_Status          0
# Urban                0
# Semi_Urban           0
# Rural                0
# dtype: int64

# %% [markdown]
# # Train and Test Split

# %%
X= df.drop(columns=['Loan_Status'])

# %%
Y = df['Loan_Status']

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 608    1
# 609    1
# 610    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 514, dtype: int32

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=0)

# %% [markdown]
# # Implenting Algorithms

# %%
from sklearn import tree
clftree = tree.DecisionTreeClassifier(max_depth = 3)

# %%
clftree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_train_pred = clftree.predict(X_train)
y_test_pred = clftree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
confusion_matrix(y_train, y_train_pred)
# Out:
# array([[ 55,  60],
#        [  0, 270]], dtype=int64)

# %%
confusion_matrix(y_test, y_test_pred)
# Out:
# array([[19, 23],
#        [ 5, 82]], dtype=int64)

# %%
accuracy_score(y_test, y_test_pred)
# Out:
# 0.7829457364341085

# %% [markdown]
# Bagging

# %%
from sklearn import tree
clftree = tree.DecisionTreeClassifier()

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag_clf = BaggingClassifier(base_estimator=clftree, n_estimators=1000,
                            bootstrap=True, n_jobs=-1,
                            random_state=42)

# %%
bag_clf.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=1000,
#                   n_jobs=-1, random_state=42)

# %%
confusion_matrix(y_test, bag_clf.predict(X_test))
# Out:
# array([[19, 23],
#        [10, 77]], dtype=int64)

# %%
accuracy_score(y_test, bag_clf.predict(X_test))
# Out:
# 0.7441860465116279

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier(n_estimators=1000, n_jobs=-1 ,random_state=42)

# %%
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, n_jobs=-1, random_state=42)

# %%
confusion_matrix(y_test, rf_clf.predict(X_test))
# Out:
# array([[19, 23],
#        [ 7, 80]], dtype=int64)

# %%
accuracy_score(y_test, rf_clf.predict(X_test))
# Out:
# 0.7674418604651163

# %% [markdown]
# # Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf_clf = RandomForestClassifier(n_estimators=250,random_state=42)

# %%
params_grid = {"max_features" : [4,5,6,7,8,9,10],
              "min_samples_split": [2, 3, 10],
              }

# %%
grid_search = GridSearchCV(rf_clf, params_grid,
                           n_jobs=-1, cv=5, scoring='accuracy')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(n_estimators=250,
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_features': [4, 5, 6, 7, 8, 9, 10],
#                          'min_samples_split': [2, 3, 10]},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'max_features': 7, 'min_samples_split': 3}

# %%
cvrf_clf = grid_search.best_estimator_

# %%
accuracy_score(y_test, cvrf_clf.predict(X_test))
# Out:
# 0.7596899224806202

# %%
confusion_matrix(y_test, cvrf_clf.predict(X_test))
# Out:
# array([[19, 23],
#        [ 8, 79]], dtype=int64)

# %% [markdown]
# For Application Creation

# %%
import pickle

# %%
pickle.dump(cvrf_clf,open('model.pkl','wb'))

# %%
model = pickle.load(open('model.pkl','rb'))

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_features=7, min_samples_split=3, n_estimators=250,
#                        random_state=42)

# %%
X.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Urban', 'Semi_Urban', 'Rural'],
#       dtype='object')
